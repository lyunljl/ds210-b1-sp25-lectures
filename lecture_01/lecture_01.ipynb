# %% [markdown]
# # DS-210: Programming for Data Science -- Section B1
#
# # Lecture 1: Class overview. Survey. Basics of data analysis.

# %% [markdown]
# ## Teaching Staff and Office Hours
#
# ### Section B1 Instructor: Thomas Gardos
# * Email: tgardos@bu.edu
# * Office hours: Tue, Thur 1:30–3:00pm @ CCDS 1623
#
# ### Teaching Assistants (shared between sections)
#
# #### TA: Zachary Gentile
# * Email: zgentile@bu.edu
# * Office hours: TBD
#
# #### TA: Ritvik Gupta
# * Email: gritvik8@bu.edu
# * Office hours: TBD
#
# #### TA: Aru Pandey
# * Email: arupande@bu.edu
# * Office hours: TBD
#
# ### Course Assistants (shared between sections)
#
# #### CA: Sam Cowans
# * Email: samc@bu.edu
# * Office hours: TBD
#
# #### CA: Sia Sharma
# * Email: sia@bu.edu
# * Office hours: TBD
#
# #### CA: Emir Tali
# * Email: etali@bu.edu
# * Office hours: TBD
#
# #### CA: Joseph Russionello
# * Email: jmrusso@bu.edu
# * Office hours: TBD

# %% [markdown]
# ## Meetings
#
# ### Lectures
# * Time: Tues/Thurs 11:00am -- 12:15pm
# * Location: SHA 110
#
# ### Discussion
#
# All discussions are on **Fridays**. Each is 50 minutes and are led by TAs.
#
# - B2: 12:20pm – 1:10pm, PSY B45
# - B3: 1:25pm – 2:15pm, FLR 122
# - B4: 2:30pm – 3:20pm CDS164
# - B5: 3:35pm – 4:25pm CDS164
#
#
# https://www.bu.edu/academics/cds/courses/cds-ds-210/
#
# Also Section A1 (same content, but _need to attend this section_)

# %% [markdown]
# ## Websites
#
# ### Piazza class forum
# https://piazza.com/bu/spring2025/ds210<br>
# If an access code is requested use 7wl1wc6mdsv
#
# * Lecture Notes
# * Announcements and additional information
# * Questions and discussions
# * Live Q&A ??
#
# ### Gradescope class location
# https://www.gradescope.com/courses/949177<br>
# If an access code is requested use G3YK6N
#
# * Homework, project, project proposal submissions
#
#
# ### Syllabus and Lecture Schedule
# [Syllabus](https://docs.google.com/document/d/e/2PACX-1vQjoejoogmlm_cZRxzTh6m55VqlXZe_5cjLtkScsMwtxnAR8zaoPLuzDwHsCqsQIR_A4TrIIJWoXrWl/pub)<br>
# [Lecture Schedule](https://docs.google.com/spreadsheets/d/e/2PACX-1vSTszIAuGA36pLOUibKCEfKTgLZdzajGtyEqM14i-aIGj_4GUzp6Fw9I5dBsI6HMzx9s39FQkqXrqk6/pubhtml) _(Subject to Frequent Updates)_

# %% [markdown]
# ## Academic Conduct Standards
# https://www.bu.edu/academics/policies/academic-conduct-code/

# %% [markdown]
# ### Collaboration Policy
#
# (Will be included in the homework instructions too.)
#
# * You may verbally collaborate on required homework problems.
# * However, **you must write your solutions independently** without showing them to other students.
# * If you choose to collaborate on a problem, **you are allowed to discuss it with at most 2 other students** currently enrolled in the class.
# * **The header of each assignment you submit must include the field “Collaborators:”** with the names of the students with whom you have had discussions concerning your solutions.
#     * If you didn’t collaborate with anyone, write “Collaborators: none.“
#     * A failure to list collaborators may result in credit deduction.
# * You may use external resources such as software documentation, textbooks, lecture notes, and videos to supplement your general understanding of the course topics.
# * You may use references such as books and online resources for well known facts. However, **you must always cite the source.**
# * You may _not_ look up answers to a homework assignment in the published literature or on the web.
# * You may _not_ share written work with anyone else.

# %% [markdown]
# ### Using AI bots
#
# (Will be included in the  homework instructions too.)
#
# * You _may_ use ChatGPT/Generative AI as a resource to help you complete the assignment.
# * However, **it must be used constructively to help you understand things you are unsure of, and be built upon with original code.**
#     * "Give me intuition about...", "Explain it in simple terms..."
# * You must cite your interaction by providing a screenshot of your prompt and the corresponding response.
# * In addition, you must  explain all code from the AI that you implement in your assignment.
#     * Touch upon how the code works and how it helped you.
#     * Failure to do so could result in credit deduction.
#
# https://www.bu.edu/cds-faculty/culture-community/gaia-policy/

# %% [markdown]
# ## Grading
# ~9 Homeworks, 1 final project, 1 midterm, 1 final.
#
# Grade will be determined as following:
# * 25% homeworks,
# * 20% midterm,
# * 25% final project,
# * 25% final exam,
# * 5% attendance.

# %% [markdown]
# ## Context
#
# * Second programming course in the data science major, after DS-110
# * Other students are welcome too!

# %% [markdown]
# ## Why Rust?
#
# * Important to learn a "systems" programming language
# * Generally, compiled languages such as Rust are needed to scale to large, efficient deployments
# * Can be 10x to 100x faster than equivalent Python
#
# ### And Rust is "memory safe"
#
# Google, Microsoft, Meta have efforts underway to move their infrastructure code to Rust
# and other memory safe languages from C/C++.
#
# ---
#
# ![image.png](attachment:image.png)
# [Whitehouse Press Release](https://www.whitehouse.gov/oncd/briefing-room/2024/02/26/press-release-technical-report/)
#
# ---
#
# ![image-2.png](attachment:image-2.png)
# [Darpa Program](https://www.darpa.mil/research/programs/translating-all-c-to-rust)
#
# ---
#
# ![image-3.png](attachment:image-3.png)
# [CISA -- The case for memory safe roadmaps](https://www.cisa.gov/sites/default/files/2023-12/The-Case-for-Memory-Safe-Roadmaps-508c.pdf)
# CISA -- Cybersecurity and Infrastructure Security Agency
#
# ---

# %% [markdown]
# ## Course Content

# %% [markdown]
# ### Part 1: Systems Knowledge (~Weeks 1 & 2)
# * Continuation of DS-110
# * Programming Languages, Operating Systems, Executables
# * File Systems and the Unix Shell
# * Git and source control management

# %% [markdown]
# ### Part 2: Rust and Basic Data structures (~Weeks 3 --> 10)
# * What is it? Why Rust?
#   - relatively new language
#   - as efficient as C/C++
#   - memory–safe
# * Basic Data structures
#   - Queues, Stacks, Trees, Binary Search
#   - Graphs

# %% [markdown]
# ### Part 3: Rust and Data Science Algorithms (~Weeks 11 --> 14)
# * ndarray vs numpy
# * Decision Trees
# * Regression, Loss functions, Accuracy metrics
# * Parallelism
# * Small project using Rust

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# * Programming (Any language) -- presuming python
# * Familiar with Jupyter Notebooks

# %% [markdown]
# * An Integrated Development Environment (IDE) such as VSCode (preferred), Cursor (a VSCode fork) or similar
# * Big-Oh notation (basic understanding)

# %% [markdown]
# ### Big-Oh Notation in Programming
#
# * **What is Big-O Notation?** Describes algorithm efficiency and scalability relative to size of input, say $n$
# * **Focus on Worst-Case (asymptotic) Scenario**  Helps analyze the upper bound of performance.
# * **Common Complexity Classes**  O($1$) (constant time), O($\log n$), O($n$), O($n \log n$), O($n^2$) (quadratic), O($n^3$) (cubic), O($2^n$) (exponential) etc.
# * **Why It Matters** Guides optimization and decision-making.
# * **Practical Examples** `Vec` operations: `push()` can be O($1$), bubble sort O($n^2$), optimal `sort()`, e.g. `timsort()` is O($n \log n$).
#
# ![image.png](attachment:744ce989-d3d3-4437-9e4d-c9ba11e25b1d.png)
# (http://interactivepython.org/courselib/static/pythonds/AlgorithmAnalysis/BigONotation.html)

# %% [markdown]
# ### Two basic approaches: Interpreted and Compiled
#
# **Interpreted**
#
# * Interactive notebooks:
#   * long tradition: Mathematica, Matlab, ...
#   * mixing code, description, visualisation
#   * Jupyter Notebook + Python can be used as a replacement of all of this
#
# **Compiled**
#
# * write a program
# * compile it
# * run it and debug
# * see the result
#
# Although for lectures, we'll be using a hybrid of Jupyter Notebooks with a Rust kernel
# thanks to the [EValuation ConteXt for Rust (Evcxr) project](https://github.com/evcxr/evcxr/).

# %% [markdown]
# ---

# %% [markdown]
# ## Quick survey
#
# * Any prerequisites you are least comfortable with?
# * What programming languages do you know? (basic/intermediate/advanced)
# * Please complete survey https://forms.gle/DdzJNRPnoofJjNjg7
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Setting up your compute environment
#
# Start by registering yourself with the Mass Open Cloud (MOC) using this URL:
#
# https://regapp.mss.mghpcc.org/
#
# It's part of the
# [Massachusetts Green High Performance Computing Center (MGHPCC)](https://www.mghpcc.org/) which is an infrastructure shared BU, Harvard, MIT, Northeastern, UMass and Yale.
#
# It's also where BU's Shared Computing Cluster is hosted.
#
# You will see the screen below.  You MUST use your bu email address to register!!!!
#
# ![image.png](attachment:image.png)
#
# Then you should see the following screen
#
# ![image-2.png](attachment:image-2.png)
#
# Then click on the "Select and Identity Provider" dropdown and pick "Boston University".

# %% [markdown]
# ## Accessing the compute environment
#
# Navigate to the following URL:
#
# https://rhods-dashboard-redhat-ods-applications.apps.shift.nerc.mghpcc.org/notebookController/spawner
#
# Click on the "Log in with Open Shift"
#
# ![image.png](attachment:image.png)
#
# Click on "mss-keycloak"
#
# ![image-2.png](attachment:image-2.png)
#
# Select one of two options:
#
# 1. Jupyter Rust:  This is for viewing the lecture notebooks.  You will not be using jupyter notebook for the homeworks
# 2. VSCode Rust: This is for writing and running your Rust coding assignments and project.
#
# The two images share the filesystem so whatever files exist in image will also exist in the other. Let's follow the live demo to see what this looks like.
#
#
# ![image-5.png](attachment:image-5.png)
#
# At the bottom of the screen, make sure to select:
#
# **Container Size:** Small <br>
# **Accelerator:** None
#
# **Environment Variables**<br>
# **Custom Variable**<br>
# **Variable Name:** CARGO_HOME<br>
# **Variable Value:** `/opt/app-root/src/.cargo`
#
# Then click on "Start Server"
#
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ## Installing Rust locally
#
# Even though you are expected to do your work on the Cloud environment, it is possible to install Rust locally.
#
# Follow the directions at https://www.rust-lang.org/tools/install.
#
# Eventually you'll probably have to use the cloud environment because of packages like NDArray.
#
# To enable Rust as a kernel for Jupyter Notebooks, follow the instructions
# [here](https://racum.blog/articles/rust-jupyter/).

# %% [markdown]
# ## In-Class Attendance Poll
#
# **Only to be answered and submitted if you are physically in class**
#
# https://piazza.com/class/m5qyw6267j12cj/post/8

# %% [markdown]
# ## Recap
#
# - Introduction to the course and setup instructions
# - How to access and use the Jupyter and VSCode environments
# - Setting up the container size and environment variables
# - Instructions for starting the server
# - Guide to installing Rust locally
# - Enabling Rust as a kernel for Jupyter Notebooks

# %% [markdown]
# ## Coming Up
#
# - **Thursday** "Overview of Programming Languages Cont'd. Basic Systems Concepts
# - **Week 2:** Introduction to Shell Commands, Git, and Basic Rust Concepts
#     - **Tuesday, 2025-01-28** "Introduction to the unix file system, shell, and git
#     - **Thursday, 2025-01-30** "Git Continued and Getting started with Rust
